# %% [markdown]
# <h2 class="spectrum">Nacteni souboru</h2>
# <style>
# .spectrum {
#   font-size: 48px;
#   text-align: center;
#   color: white;
#   animation: colorCycle 5s infinite linear;
# }
# @keyframes colorCycle {
#   0% { color: red; }
#   25% { color: yellow; }
#   50% { color: lime; }
#   75% { color: cyan; }
#   100% { color: red; }
# }
# </style>

# %%
import pandas as pd
df=pd.read_csv(r"data\countries of the world.csv", sep=",")   # https://www.kaggle.com/datasets/fernandol/countries-of-the-world/code
df
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
df=pd.read_table(r"data\countries of the world.txt", sep='|') #oddelit tabulatorom   (\t) (',') | (pipe)
df
# Out:
#         Název země                  Region    Počet obyvatel   \
# 0      Afghanistan    ASIA (EX. NEAR EAST)           31056997
# 1          Albania          EASTERN EUROPE            3581655
# 2          Algeria         NORTHERN AFRICA           32930091
# 3          Andorra          WESTERN EUROPE              71201
# 4           Angola      SUB-SAHARAN AFRICA           12127071
# 5        Argentina     LATIN AMER. & CARIB           39921833
# 6          Armenia                     CIS            2982904
# 7        Australia                 OCEANIA           20264082
# 8          Austria          WESTERN EUROPE            8192880
# 9       Azerbaijan                     CIS            7961619
# 10      Bangladesh    ASIA (EX. NEAR EAST)          147365352
# 11         Belgium          WESTERN EUROPE           10379067
# 12          Brazil     LATIN AMER. & CARIB          188078227
# 13          Canada        NORTHERN AMERICA           33098932
# ...

# %%
df=pd.read_json(r"data\countries of the world.json")
df
# Out:
#         Název země                Region  Počet obyvatel  HDP na osobu ($)
# 0      Afghanistan  ASIA (EX. NEAR EAST)        31056997               700
# 1          Albania        EASTERN EUROPE         3581655              4500
# 2          Algeria       NORTHERN AFRICA        32930091              6000
# 3          Andorra        WESTERN EUROPE           71201             19000
# 4           Angola    SUB-SAHARAN AFRICA        12127071              1900
# 5        Argentina   LATIN AMER. & CARIB        39921833             11200
# 6          Armenia                   CIS         2982904              3500
# 7        Australia               OCEANIA        20264082             30000
# 8          Austria        WESTERN EUROPE         8192880             30000
# 9       Azerbaijan                   CIS         7961619              3400
# 10      Bangladesh  ASIA (EX. NEAR EAST)       147365352              1900
# ...

# %%
import pandas as pd
df=pd.read_excel(r"data\countries of the world.xlsx", sheet_name='Počet obyvatel')  # stranka v Excely 
df
# Out:
#         Název země                Region  Počet obyvatel  HDP na osobu ($)
# 0            China  ASIA (EX. NEAR EAST)      1313973713              5000
# 1            India  ASIA (EX. NEAR EAST)      1095351995              2900
# 2    United States      NORTHERN AMERICA       298444215             37800
# 3        Indonesia  ASIA (EX. NEAR EAST)       245452739              3600
# 4           Brazil   LATIN AMER. & CARIB       188078227              8600
# 5         Pakistan  ASIA (EX. NEAR EAST)       165803560              2100
# 6       Bangladesh  ASIA (EX. NEAR EAST)       147365352              1900
# 7           Russia                   CIS       142893540              8900
# 8            Japan  ASIA (EX. NEAR EAST)       127463611             28200
# 9           Mexico   LATIN AMER. & CARIB       107449525              9000
# 10         Vietnam  ASIA (EX. NEAR EAST)        84402966              2500
# ...

# %%
pd.set_option('display.max_row', 55)  # zobrazit vsechny radky
pd.set_option('display.max_columns', 20)  # zobrazit vsechny sloupce

# %%
df2=pd.read_excel(r"data\countries of the world.xlsx", sheet_name='Počet obyvatel')  # stranka v Excely 
df2
# Out:
#         Název země                Region  Počet obyvatel  HDP na osobu ($)
# 0            China  ASIA (EX. NEAR EAST)      1313973713              5000
# 1            India  ASIA (EX. NEAR EAST)      1095351995              2900
# 2    United States      NORTHERN AMERICA       298444215             37800
# 3        Indonesia  ASIA (EX. NEAR EAST)       245452739              3600
# 4           Brazil   LATIN AMER. & CARIB       188078227              8600
# 5         Pakistan  ASIA (EX. NEAR EAST)       165803560              2100
# 6       Bangladesh  ASIA (EX. NEAR EAST)       147365352              1900
# 7           Russia                   CIS       142893540              8900
# 8            Japan  ASIA (EX. NEAR EAST)       127463611             28200
# 9           Mexico   LATIN AMER. & CARIB       107449525              9000
# 10         Vietnam  ASIA (EX. NEAR EAST)        84402966              2500
# ...

# %%
df2.info()  # informace o datovem ramci
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Název země        24 non-null     object
#  1   Region            24 non-null     object
#  2   Počet obyvatel    24 non-null     int64
#  3   HDP na osobu ($)  24 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 900.0+ bytes

# %%
df2.shape  #pocet radku a sloupcu
# Out:
# (24, 4)
